# %%
# !pip install tensorflow

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X = dataset.iloc[:,3:13]
y = dataset.iloc[:,13]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
geography = pd.get_dummies(X['Geography'],drop_first=True)
gender = pd.get_dummies(X['Gender'],drop_first=True)

# %%
X=X.drop(['Geography','Gender'],axis=1)

# %%
X = pd.concat([X,geography,gender],axis=1)

# %%
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain   Male
# 0               1        101348.88    False  False  False
# 1               1        112542.58    False   True  False
# 2               0        113931.57    False  False  False
# 3               0         93826.63    False  False  False
# 4               1         79084.10    False   True  False

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %%
X_test
# Out:
# array([[-0.55204276, -0.36890377,  1.04473698, ...,  1.75486502,
#         -0.57369368, -1.09168714],
#        [-1.31490297,  0.10961719, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        [ 0.57162971,  0.30102557,  1.04473698, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        ...,
#        [-0.74791227, -0.27319958, -1.37744033, ..., -0.5698444 ,
#          1.74309049,  0.91601335],
#        [-0.00566991, -0.46460796, -0.33936434, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-0.79945688, -0.84742473,  1.04473698, ...,  1.75486502,
#         -0.57369368,  0.91601335]])

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU, PReLU, ELU, ReLU
from tensorflow.keras.layers import Dropout

# %%
classifier= Sequential()

# %%
classifier.add(Dense(units=11,activation='relu'))

# %%
classifier.add(Dense(units=7,activation='relu'))
classifier.add(Dropout(0.2))

# %%
classifier.add(Dense(units=6,activation='relu'))
classifier.add(Dropout(0.3))

# %%
classifier.add(Dense(1,activation='sigmoid'))

# %%
import tensorflow
opt = tensorflow.keras.optimizers.Adam(learning_rate=0.01)

# %%
classifier.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
import tensorflow as tf
early_stopping=tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.0001,
    patience=20,
    verbose=1,
    mode='auto',
    baseline=None,
    restore_best_weights=False
)

# %%
model= classifier.fit(X_train,y_train,validation_split=0.33,batch_size=10,epochs=1000,callbacks=early_stopping)
# Out:
# Epoch 1/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.7955 - loss: 0.4722 - val_accuracy: 0.7955 - val_loss: 0.4339
# Epoch 2/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.4332 - val_accuracy: 0.7955 - val_loss: 0.4185
# Epoch 3/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7962 - loss: 0.4251 - val_accuracy: 0.7955 - val_loss: 0.4207
# Epoch 4/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.4177 - val_accuracy: 0.7955 - val_loss: 0.4067
# Epoch 5/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.4161 - val_accuracy: 0.7955 - val_loss: 0.4011
# Epoch 6/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.4086 - val_accuracy: 0.7955 - val_loss: 0.4011
# Epoch 7/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.4123 - val_accuracy: 0.7955 - val_loss: 0.4002
# Epoch 8/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.4135 - val_accuracy: 0.7955 - val_loss: 0.3999
# Epoch 9/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7962 - loss: 0.4068 - val_accuracy: 0.7955 - val_loss: 0.3921
# Epoch 10/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.4054 - val_accuracy: 0.7955 - val_loss: 0.4037
# Epoch 11/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.4159 - val_accuracy: 0.7955 - val_loss: 0.3902
# Epoch 12/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7964 - loss: 0.4028 - val_accuracy: 0.7955 - val_loss: 0.4018
# Epoch 13/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.4056 - val_accuracy: 0.7955 - val_loss: 0.4073
# Epoch 14/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7962 - loss: 0.4001 - val_accuracy: 0.7955 - val_loss: 0.4175
# Epoch 15/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7962 - loss: 0.4022 - val_accuracy: 0.7955 - val_loss: 0.3945
# Epoch 16/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.3971 - val_accuracy: 0.7955 - val_loss: 0.4301
# Epoch 17/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7985 - loss: 0.3982 - val_accuracy: 0.7955 - val_loss: 0.3943
# Epoch 18/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7972 - loss: 0.3983 - val_accuracy: 0.7955 - val_loss: 0.4014
# Epoch 19/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8121 - loss: 0.3984 - val_accuracy: 0.7955 - val_loss: 0.3944
# Epoch 20/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7962 - loss: 0.4021 - val_accuracy: 0.7955 - val_loss: 0.3921
# Epoch 21/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8015 - loss: 0.3973 - val_accuracy: 0.7955 - val_loss: 0.3952
# Epoch 22/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8011 - loss: 0.4001 - val_accuracy: 0.7955 - val_loss: 0.3998
# Epoch 23/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7962 - loss: 0.3979 - val_accuracy: 0.7955 - val_loss: 0.4079
# Epoch 24/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8057 - loss: 0.3971 - val_accuracy: 0.8364 - val_loss: 0.4013
# Epoch 25/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8308 - loss: 0.3819 - val_accuracy: 0.8463 - val_loss: 0.3909
# Epoch 26/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8377 - loss: 0.3817 - val_accuracy: 0.8360 - val_loss: 0.3848
# Epoch 27/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8362 - loss: 0.3808 - val_accuracy: 0.8474 - val_loss: 0.3862
# Epoch 28/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8382 - loss: 0.3792 - val_accuracy: 0.8474 - val_loss: 0.3858
# Epoch 29/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8347 - loss: 0.3828 - val_accuracy: 0.8372 - val_loss: 0.3814
# Epoch 30/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8322 - loss: 0.3762 - val_accuracy: 0.8417 - val_loss: 0.3756
# Epoch 31/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8358 - loss: 0.3697 - val_accuracy: 0.8425 - val_loss: 0.3961
# Epoch 32/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8362 - loss: 0.3707 - val_accuracy: 0.8542 - val_loss: 0.3961
# Epoch 33/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8328 - loss: 0.3793 - val_accuracy: 0.8145 - val_loss: 0.3912
# Epoch 34/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8364 - loss: 0.3789 - val_accuracy: 0.8406 - val_loss: 0.3903
# Epoch 35/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8421 - loss: 0.3757 - val_accuracy: 0.8489 - val_loss: 0.3988
# Epoch 36/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8442 - loss: 0.3741 - val_accuracy: 0.8519 - val_loss: 0.3814
# Epoch 37/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8513 - loss: 0.3682 - val_accuracy: 0.8550 - val_loss: 0.3787
# Epoch 38/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8399 - loss: 0.3684 - val_accuracy: 0.8466 - val_loss: 0.3805
# Epoch 39/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8395 - loss: 0.3644 - val_accuracy: 0.8440 - val_loss: 0.4010
# Epoch 40/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8408 - loss: 0.3677 - val_accuracy: 0.8508 - val_loss: 0.3809
# Epoch 41/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8410 - loss: 0.3647 - val_accuracy: 0.8497 - val_loss: 0.3876
# Epoch 42/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8399 - loss: 0.3707 - val_accuracy: 0.8497 - val_loss: 0.3869
# Epoch 43/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8425 - loss: 0.3657 - val_accuracy: 0.8425 - val_loss: 0.3836
# Epoch 44/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8451 - loss: 0.3672 - val_accuracy: 0.8459 - val_loss: 0.3812
# Epoch 45/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8293 - loss: 0.3714 - val_accuracy: 0.8406 - val_loss: 0.3762
# Epoch 46/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8350 - loss: 0.3627 - val_accuracy: 0.8478 - val_loss: 0.4084
# Epoch 47/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8388 - loss: 0.3800 - val_accuracy: 0.8455 - val_loss: 0.3857
# Epoch 48/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8419 - loss: 0.3675 - val_accuracy: 0.8444 - val_loss: 0.4007
# Epoch 49/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8390 - loss: 0.3643 - val_accuracy: 0.8466 - val_loss: 0.4285
# Epoch 50/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8474 - loss: 0.3629 - val_accuracy: 0.8463 - val_loss: 0.3817
# Epoch 50: early stopping

# %%
model.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
plt.plot(model.history['accuracy'])
plt.plot(model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title('loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred>=0.5)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[1481,  114],
#        [ 173,  232]])

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,y_pred)

# %%
score
# Out:
# 0.8565
